# %%
import pandas as pd

df = pd.read_parquet("USD_60_indicators/STORJUSD_60.parquet")
df.head()
# Out:
#     timestamp     open     high   low    close        volume  trades  \
# 0  1594818000  0.19000  0.19000  0.18  0.18000    149.850896     3.0
# 1  1594821600  0.19000  0.20900  0.18  0.18500  37359.559421    21.0
# 2  1594825200  0.18000  0.18500  0.18  0.18500   8045.000000    15.0
# 3  1594828800  0.18594  0.20990  0.18  0.18000  68886.414357    31.0
# 4  1594832400  0.18001  0.19776  0.18  0.19776  69008.784229    50.0
#
#    log_return    return  volume_change  ...  ema_diff_norm_24_120  \
# 0   -0.054067 -0.052632            NaN  ...              0.000000
# 1    0.027399  0.027778     248.311552  ...              0.001715
# 2    0.000000  0.000000      -0.784660  ...              0.003265
# 3   -0.027399 -0.027027       7.562637  ...              0.003030
# 4    0.094097  0.098667       0.001776  ...              0.008185
#
#    price_ema_diff_12  macd_hist  realized_vol_24  weighted_vol_24  \
# 0           0.000000   0.000000         0.052632         0.052632
# ...

# %%
df.info()
df.describe()
df.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41291 entries, 0 to 41290
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   timestamp             41291 non-null  int64
#  1   open                  39469 non-null  float64
#  2   high                  36264 non-null  float64
#  3   low                   36264 non-null  float64
#  4   close                 39469 non-null  float64
#  5   volume                36264 non-null  float64
#  6   trades                36264 non-null  float64
#  7   log_return            39469 non-null  float64
#  8   return                39469 non-null  float64
#  9   volume_change         36263 non-null  float64
#  10  close_to_high         36264 non-null  float64
#  11  close_to_low          36264 non-null  float64
#  12  log_price_range       36264 non-null  float64
#  13  ma_zscore_12          39464 non-null  float64
# ...

# %%
df.to_csv("STORJUSD_60.csv", index=False)
